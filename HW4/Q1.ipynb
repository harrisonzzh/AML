# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from data_fix import *

# %% [markdown]
# (a)

# %% [markdown]
# * This network has 9 layers.
# * Each layer is extracting features. The first couple layers are capturing the details of the features such as corners and edges, and the last few layers are capturing the more board features such as shapes.

# %% [markdown]
# (b) <br>
# * Loss means error rate that the model made during predicting of all the unknow pixels.
# * The actual loss function is total L2

# %% [markdown]
# (c)

# %%
plt.figure(figsize = (9,6))
plt.plot(range(len(layer_9f[1:])), layer_9f[1:])
plt.ylabel('loss')
plt.xlabel('time')
plt.show()

# %% [markdown]
# (d)

# %%
plt.figure(figsize = (9,6))
plt.plot(range(len(layer_9f[1:])), layer_9f[1:], label='original')
plt.plot(range(len(layer_9wc[0:300:3])), layer_9wc[0:300:3], label='changing learning rate')
plt.ylabel('loss')
plt.xlabel('time')
plt.legend()
plt.show()

# %% [markdown]
# Even though we didn't lower the learning rate sharply, we still can notice the orange line converge faster than the blue line.

# %% [markdown]
# (e)

# %%
plt.figure(figsize = (9,6))
plt.plot(range(len(layer_9f[1:])), layer_9f[1:], label='9_layer')
#plt.plot(range(len(layer_7f)), layer_7f, label='7_layer')
plt.plot(range(len(layer_5f)), layer_5f, label='5_layer')
plt.plot(range(len(layer_4f)), layer_4f, label='4_layer')
plt.plot(range(len(layer_2f)), layer_2f, label='2_layer')

plt.ylabel('loss')
plt.xlabel('time')
plt.legend()
plt.show()

# %% [markdown]
# After the we reduce to two layers, the result became useless.

# %% [markdown]
# (f)

# %%
plt.figure(figsize = (9,6))
plt.plot(range(len(layer_9f[1:])), layer_9f[1:], label='9_layer')
plt.plot(range(len(layer_12f[1:])), layer_12f[1:], label='12_layer')

plt.ylabel('loss')
plt.xlabel('time')
plt.legend() 
plt.show()

# %% [markdown]
# By adding three more layers, the performance did not get better at all.
